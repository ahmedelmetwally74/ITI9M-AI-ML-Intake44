# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\bios\pakistan_intellectual_capital.csv")
df
# Out:
#       Unnamed: 0    S#            Teacher Name  \
# 0              2     3         Dr. Abdul Basit
# 1              4     5         Dr. Waheed Noor
# 2              5     6        Dr. Junaid Baber
# 3              6     7     Dr. Maheen Bakhtyar
# 4             24    25             Samina Azim
# ...          ...   ...                     ...
# 1137        1974  1975        Dr. Ahmar Rashid
# 1138        1975  1976       Dr. Fawad Hussain
# 1139        1977  1978    Dr. Rashad M Jillani
# 1140        1979  1980  Dr. Shahabuddin Ansari
# 1141        1980  1981         Dr. Sajid Anwar
#
#                University Currently Teaching  \
# 0                  University of Balochistan
# 1                  University of Balochistan
# 2                  University of Balochistan
# 3                  University of Balochistan
# 4     Sardar Bahadur Khan Women's University
# ...                                      ...
# 1137             Ghulam Ishaq Khan Institute
# ...

# %%
df['Country'].unique()
# Out:
# array(['Thailand', 'Pakistan', 'germany', 'Austria', 'Australia', 'UK',
#        'China', 'France', 'USofA', 'SouthKorea', 'Malaysia', 'Sweden',
#        'Italy', 'Canada', 'Norway', 'Ireland', 'New Zealand', 'Urbana',
#        'Portugal', 'Russian Federation', 'USA', 'Finland', ' USA',
#        'Netherland', ' Germany', ' Sweden', ' New Zealand', 'Greece',
#        'Turkey', 'South Korea', 'Macau', 'Singapore', 'Spain', 'Japan',
#        'HongKong', 'Saudi Arabia', 'Mauritius', 'Scotland'], dtype=object)

# %%
# Convert to lowercase and remove leading/trailing whitespaces
df['Country'] = df['Country'].str.lower().str.strip()

# %%
df['Country'].unique()
# Out:
# array(['thailand', 'pakistan', 'germany', 'austria', 'australia', 'uk',
#        'china', 'france', 'usofa', 'southkorea', 'malaysia', 'sweden',
#        'italy', 'canada', 'norway', 'ireland', 'new zealand', 'urbana',
#        'portugal', 'russian federation', 'usa', 'finland', 'netherland',
#        'greece', 'turkey', 'south korea', 'macau', 'singapore', 'spain',
#        'japan', 'hongkong', 'saudi arabia', 'mauritius', 'scotland'],
#       dtype=object)

# %%
# df['Country'].apply(lamda x:str(x).lower())

# %%
corrections = {
    'usofa': 'usa',
    'germany': 'germany',
    'new zealand': 'new zealand',
    ' usa': 'usa',
    ' germany': 'germany',
    ' sweden': 'sweden',
    ' new zealand': 'new zealand',
    'southkorea': 'south korea',
    'macau': 'macau',
    'hongkong': 'hong kong'
}

# %%
df['Country'] = df['Country'].replace(corrections)

# %%
df['Country'].unique()
# Out:
# array(['thailand', 'pakistan', 'germany', 'austria', 'australia', 'uk',
#        'china', 'france', 'usa', 'south korea', 'malaysia', 'sweden',
#        'italy', 'canada', 'norway', 'ireland', 'new zealand', 'urbana',
#        'portugal', 'russian federation', 'finland', 'netherland',
#        'greece', 'turkey', 'macau', 'singapore', 'spain', 'japan',
#        'hong kong', 'saudi arabia', 'mauritius', 'scotland'], dtype=object)
