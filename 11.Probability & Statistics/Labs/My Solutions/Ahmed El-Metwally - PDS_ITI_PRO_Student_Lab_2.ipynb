# %% [markdown]
# # Conditional probabilities

# %%
from itertools import product

# %%
# no. of a coins
n = 3 

# Sample Space : 8
list(product(['H','T'],repeat=3))
# Out:
# [('H', 'H', 'H'),
#  ('H', 'H', 'T'),
#  ('H', 'T', 'H'),
#  ('H', 'T', 'T'),
#  ('T', 'H', 'H'),
#  ('T', 'H', 'T'),
#  ('T', 'T', 'H'),
#  ('T', 'T', 'T')]

# %%
# no. of a coins
n = 3 

# Sample Space : 8
# Out:
# [('H', 'H', 'H'),
#  ('H', 'H', 'T'),
#  ('H', 'T', 'H'),
#  ('H', 'T', 'T'),
#  ('T', 'H', 'H'),
#  ('T', 'H', 'T'),
#  ('T', 'T', 'H'),
#  ('T', 'T', 'T')]

# %%
n = 3 # no. of a coins

 #create the sample space
omega = set(product(['H','T'],repeat=3))
print(omega)
print(len(omega))
# Out:
# {('T', 'H', 'H'), ('H', 'T', 'T'), ('T', 'T', 'T'), ('T', 'H', 'T'), ('H', 'H', 'T'), ('H', 'T', 'H'), ('H', 'H', 'H'), ('T', 'T', 'H')}
# 8

# %%
n = 3 # no. of a coins

 #create the sample space
omega = 
print(omega)
print(len(omega))
# Out:
# {('T', 'T', 'H'), ('H', 'H', 'T'), ('T', 'H', 'H'), ('H', 'H', 'H'), ('H', 'T', 'T'), ('T', 'T', 'T'), ('H', 'T', 'H'), ('T', 'H', 'T')}
# 8

# %%
A = {i for i in omega if i[0] == 'T'}     #Event that first tossing is tail
B = {i for i in omega if i.count('T')==2} #Event of having exactly two tails

# %%
def Prob(X):
    return len(X)/len(omega)

def Cond_Prob (X,Y): 
    return len(X.intersection(Y)) / len(Y)

# %%
print(Prob(A))
# Out:
# 0.5

# %%
A
# Out:
# {('T', 'H', 'H'), ('T', 'H', 'T'), ('T', 'T', 'H'), ('T', 'T', 'T')}

# %%
B
# Out:
# {('H', 'T', 'T'), ('T', 'H', 'T'), ('T', 'T', 'H')}

# %%
Prob(B)
# Out:
# 0.375

# %%
Cond_Prob(A,B)
# Out:
# 0.6666666666666666

# %%
Prob(A) * Prob(B)
# Out:
# 0.1875

# %%
def are_indep(X,Y):
    return Prob(X.intersection(Y)) == Prob(X) * Prob(Y)

# %%
are_indep(A,B)
# Out:
# False

# %%
C = {i for i in omega if i[1] == 'H'} #Event that second tossing is head
C
# Out:
# {('H', 'H', 'H'), ('H', 'H', 'T'), ('T', 'H', 'H'), ('T', 'H', 'T')}

# %%
are_indep(A,C)
# Out:
# True

# %% [markdown]
# # LAB 2: Probability Distributions and Statistical Data Visualization
#
# In this lab you will use python to study the following topics:
#
# - How to sample from different distributions functions.
# - Calculate arthemitic mean, sample variance, and sample standard deviation for different distributions functions.
# - Statistical data visualization using seaborn library

# %% [markdown]
# # First: you should run this cell

# %%
# Make all numpy available via shorter 'np' prefix
import numpy as np

from scipy import stats


# matplotlib library
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Problem 1
# a) Use the numpy function [numpy.random.normal](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to generate a standard Gaussian random variable $X$ (zero mean and unit variance).
#
# - Use histogram to plot the estimated PDF of the random variable $X$
# - Compute the true "analytical" PDF -using the equation- of $X$ . Plot the true PDF on the top of the histogram figure.
# - Calculate the sample mean and the sample variance.

# %% [markdown]
# ### True/Analytical PDF
# ![image.png](attachment:image.png)

# %% [markdown]
# ## using `numpy`

# %%
# Ways to Make a sample 
# First Way 
x = np.random.normal(loc=0 ,scale=np.sqrt(1),size =100)
plt.hist(x)
plt.grid()

# %%
# Second Way
X = stats.norm(0, np.sqrt(1))
x = X.rvs(size = 100)
plt.grid()
plt.hist(x)
# Out:
# (array([ 2.,  3.,  6.,  7., 21., 27., 18.,  9.,  5.,  2.]),
#  array([-3.0967589 , -2.52975378, -1.96274867, -1.39574356, -0.82873845,
#         -0.26173333,  0.30527178,  0.87227689,  1.439282  ,  2.00628712,
#          2.57329223]),
#  <BarContainer object of 10 artists>)

# %%
def normal_pdf (x,mu,sigma):
    return (1/(sigma*np.sqrt(2*np.pi)))*np.exp((-1/2)*((x-mu)/sigma)**2)

# %%
# Analytical/Theoretical PDF 
x = np.linspace(-5,5,100)
y = normal_pdf(x,0,1)
plt.plot(x,y,color='r')

# Histogram/Experimental PDF  
rvs = np.random.normal(loc = 0, scale = 1,size = 10000)
plt.hist(rvs, density = True,bins =100);

# %%
# Analytical / Theoretiacl PDF
x = np.linspace(-5,5,150)
y = stats.norm.pdf(x,loc =0,scale=1)
plt.plot(x,y,color='b')
plt.grid()

# %%
# Histogram / Expermental PDF 
X = stats.norm(0, np.sqrt(1))
rvs = X.rvs(1000000)
plt.hist(rvs, density =True,bins = 100);
plt.grid()

# %%
#type your code here:
# Out:
# Sample mean: 0.01589717727652419
# Sample variance: 0.9944424475117524

# %% [markdown]
# ## using `scipy`

# %%
# Analytical / Theoretiacl PDF
x = np.linspace(-5,5,150)
y = stats.norm.pdf(x,loc =0,scale=1)
plt.plot(x,y,color='r')
# Histogram / Expermental PDF 
X = stats.norm(0, np.sqrt(1))
rvs = X.rvs(1000000)
plt.hist(rvs, density =True,bins = 100);
plt.grid()
print("Sample mean:",rvs.mean())
print("Sample variance:",rvs.var())
# Out:
# Sample mean: 0.0005638282652918175
# Sample variance: 1.000178694392919

# %%
#type your code here:
# Out:
# Sample mean: 0.01589717727652419
# Sample variance: 0.9944424475117524

# %% [markdown]
# - Compute the true "analytical" PDF using [scipy.stats.norm.pdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html). Plot the true PDF on the top of the histogram figure.
# - Compute the CDF using [scipy.stats.norm.cdf](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html), then plot it.

# %%
# Analytical/Theoretical PDF 

x = np.linspace(-5,5,100)
y = normal_pdf(x,0,1)
plt.plot(x,y,color='r',label='PDF')


# Histogram/Experimental PDF  
X = stats.norm(0, np.sqrt(1))
rvs = X.rvs(1000)
plt.hist(rvs, density =True,bins = 100, label='Hist');

# Theoretical CDF 
y = stats.norm.cdf(rvs, loc=0, scale = 1)
plt.plot(data_sorted, p, color='orange');


#Experimental CDF 
# rvs = X.rvs(10000)
data_sorted = np.sort(rvs)
p = np.linspace(0,1,len(rvs))
plt.plot(data_sorted, p, color = 'magenta')
plt.grid()

# %%
#type your code here:
|

# %% [markdown]
# b) Repeat (a) for a Gaussian random variable $Y$ with $mean=3$ and $variance=4$.

# %%
# Analytical/Theoretical PDF for Y
x = np.linspace(-5, 10, 100)
y = normal_pdf(x, 3, np.sqrt(4))
plt.plot(x, y, color='b')

# Histogram/Experimental PDF
rvs = np.random.normal(loc=3, scale=2, size=10000)
plt.hist(rvs, density=True, bins=100)

# Analytical/Theoretical PDF using scipy.stats
x_stats = np.linspace(-5, 10, 150)
y_stats = stats.norm.pdf(x_stats, loc=3, scale=2)
plt.plot(x_stats, y_stats, color='r')

mean = np.mean(rvs)
variance = np.var(rvs)
print(f"Sample mean: {mean}")
print(f"Sample variance: {variance}")

plt.grid()
plt.show()
# Out:
# Sample mean: 2.9859860108690084
# Sample variance: 4.018983687219496

# %%
#type your code here:
# Out:
# Sample mean: 2.9570133538646415
# Sample variance: 3.9437893311031664

# %%
# Analytical/Theoretical PDF
x = np.linspace(-5, 10, 100)
y = normal_pdf(x, 3, 2)
plt.plot(x, y, color='r', label='Analytical PDF')

# Histogram/Experimental PDF
rvs = np.random.normal(loc=3, scale=2, size=10000)
plt.hist(rvs, density=True, bins=100, label='Experimental PDF');

# Analytical/Theoretical CDF 
y = stats.norm.cdf(rvs, loc=3, scale=2)
plt.plot(data_sorted, p ,color="orange", label='Analytical CDF')

#Experimental CDF
data_sorted = np.sort(rvs)
p = np.linspace(0, 1, len(rvs))
plt.plot(data_sorted, p, color="green", label='Experimental CDF' )

plt.legend()
plt.grid()

# %%
#type your code here:

# %% [markdown]
# C) Repeat (a) for an exponential random variable with $\lambda = 1$ using [numpy.random.exponential](https://numpy.org/doc/stable/reference/random/generated/numpy.random.exponential.html), and [scipy.stats.expon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html#scipy.stats.expon)

# %%
# Analytical / Theoretical PDF
x = np.linspace(0, 5, 100)
y = stats.expon.pdf(x, scale=1)
plt.plot(x, y, color='r', label='Analytical PDF')

# Histogram / Experimental PDF
rvs = np.random.exponential( scale=1, size=10000)
plt.hist(rvs, density=True, bins=100, label='Experimental PDF');

plt.legend()
plt.grid()
print("Sample mean:", rvs.mean())
print("Sample variance:", rvs.var())
# Out:
# Sample mean: 1.029630835648543
# Sample variance: 1.034987338587258

# %%
#type your code here:
# Out:
# Sample mean: 1.0011220637243747
# Sample variance: 1.002224188207073

# %%
# Analytical/Theoretical PDF
x = np.linspace(0, 5, 100)
y = stats.expon.pdf(x, scale=1)
plt.plot(x, y, color='r', label='Analytical PDF')

# Histogram/Experimental PDF
rvs = np.random.exponential(scale=1, size=10000)
plt.hist(rvs, density=True, bins=50, label='Experimental PDF');

# Analytical/Theoretical CDF 
y = stats.expon.cdf(rvs, scale=1)
plt.plot(data_sorted, p ,color="orange", label='Analytical CDF')

#Experimental CDF
data_sorted = np.sort(rvs)
p = np.linspace(0, 1, len(rvs))
plt.plot(data_sorted, p, color="green", label='Experimental CDF' )

plt.legend()
plt.grid()

# %%
#type your code here:

# %% [markdown]
# d) Repeat (a) for an exponential random variable with $\lambda = 0.5$

# %%
# Analytical/Theoretical PDF
x = np.linspace(0, 5, 100)
y = stats.expon.pdf(x, scale=2)
plt.plot(x, y, color='r', label='Analytical PDF')

# Histogram/Experimental PDF
rvs = np.random.exponential(scale=2, size=10000)
plt.hist(rvs, density=True, bins=100, label='Experimental PDF');

plt.legend()
plt.grid()
print("Sample mean:", rvs.mean())
print("Sample variance:", rvs.var())
# Out:
# Sample mean: 1.999625806388427
# Sample variance: 4.0288980474425236

# %%
#type your code here:
# Out:
# Sample mean: 1.9959330233482213
# Sample variance: 4.0065581143160705

# %%
# Analytical/Theoretical PDF
x = np.linspace(0, 5, 100)
y = stats.expon.pdf(x, scale=2)
plt.plot(x, y, color='r', label='Analytical PDF')

# Histogram/Experimental PDF
rvs = np.random.exponential(scale=2, size=10000)
plt.hist(rvs, density=True, bins=100, label='Experimental PDF');

# Analytical/Theoretical CDF 
y = stats.expon.cdf(rvs, scale=2)
plt.plot(data_sorted, p ,color="orange", label='Analytical CDF');

#Experimental CDF
data_sorted = np.sort(rvs)
p = np.linspace(0, 1, len(rvs))
plt.plot(data_sorted, p, color="green", label='Experimental CDF' )

plt.legend()
plt.grid()

# %%
#type your code here:

# %% [markdown]
# e) Repeat for an binomial random variable with $n = 5$ and $p = 0.5$

# %%
# Theoretical PMF 
x = np.arange(0, 6)
y = stats.binom.pmf(x, n=5, p=0.5)
plt.stem(x, y, linefmt='r-', markerfmt=' ', basefmt='b ',label ="Theoretical PMF")

# Histogram/Experimental PMF
rvs = np.random.binomial(n=5, p=0.5, size=10000)
plt.hist(rvs, density=True, bins=np.arange(7)-0.5,label ="Histogram");
plt.legend()
plt.grid()
print("Sample mean:", rvs.mean())
print("Sample variance:", rvs.var())
# Out:
# Sample mean: 2.4895
# Sample variance: 1.2486897499999998

# %%
#type your code here:
# Out:
# Sample mean: 2.499239
# Sample variance: 1.2508546717336713

# %%
# Theoretical PMF 
x = np.arange(0, 6)
y = stats.binom.pmf(x, n=5, p=0.5)
plt.stem(x, y, linefmt='r-', markerfmt=' ', basefmt=' ',label="PMF")

# Theoretical CDF 
y = stats.binom.cdf(x, n=5, p=0.5)
plt.step(x, y,label="CDF");
plt.grid()
plt.legend()

# %%
#type your code here:

# %% [markdown]
# f) Repeat for an binomial random variable with $n = 20$ and $p = 0.5$

# %%
# Theoretical PMF 
x = np.arange(0, 21)
y = stats.binom.pmf(x, n=20, p=0.5)
plt.stem(x, y, linefmt='r-', markerfmt='ro', basefmt='b ',label="PMF")

# Histogram/Experimental PMF 
rvs = np.random.binomial(n=20, p=0.5, size=10000)
plt.hist(rvs, density=True, bins=np.arange(22)-0.5,label="Histogram");

print("Sample mean:", rvs.mean())
print("Sample variance:", rvs.var())
plt.grid()
plt.legend()
# Out:
# Sample mean: 10.0064
# Sample variance: 4.955959040000001

# %%
#type your code here:
# Out:
# Sample mean: 10.000802
# Sample variance: 4.998190354986355

# %%
# Theoretical PMF
x = np.arange(0, 21)
y = stats.binom.pmf(x, n=20, p=0.5)
plt.stem(x, y, linefmt='r-', markerfmt=' ', basefmt='b ',label="Theoretical PMF")

# Theoretical CDF
y = stats.binom.cdf(x, n=20, p=0.5)
plt.step(x, y,label="Theoretical CDF")

plt.legend()
plt.grid()

# %%
#type your code here:

# %% [markdown]
# # Problem 2
#
# (a) In this problem, you will use [seaborn](https://seaborn.pydata.org/) for statistical data visualization:
#
# - Load the penguins data `df = sns.load_dataset("penguins")`.
# - Display the first 5 rows of the dataset and use any relevant functions that can help you to understand the data.

# %%
import pandas as pd
df = pd.read_csv(r"E:\ITI AI&ML\10.Data Preparation\Datasets\penguins.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           1  Adelie  Torgersen            39.1           18.7
# 1           2  Adelie  Torgersen            39.5           17.4
# 2           3  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen             NaN            NaN
# 4           5  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %%
df.describe()
# Out:
#        Unnamed: 0  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df = df.drop(columns=['year'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# - Use seaborn different plots to explore the data.
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
sns.pairplot(df, diag_kind="kde")

# %%
#type your code here:

# %% [markdown]
# - [heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html) : `sns.heatmap(df.corr(), annot=True)`

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#type your code here:
# Out:
# <AxesSubplot:>

# %% [markdown]
# - [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
sns.pairplot(df, hue="species")

# %%
#type your code here:

# %%
sns.pairplot(df, hue="sex")

# %%
#type your code here:

# %%
sns.pairplot(df, hue="island")

# %%
#type your code here:

# %% [markdown]
# - [displot](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %%
sns.displot(data=df, x="flipper_length_mm", hue="species", col="sex")

# %%
sns.displot(df, x="flipper_length_mm", col="species", row="sex", 
            binwidth=3, height=3, facet_kws=dict(margin_titles=True))

# %%
#type your code here:

# %%
sns.displot(df, x="flipper_length_mm", col="island", row="sex", 
            binwidth=3, height=3, facet_kws=dict(margin_titles=True))

# %%
#type your code here:

# %%
#type your code here:

# %% [markdown]
# - [jointplot](https://seaborn.pydata.org/generated/seaborn.jointplot.html)

# %%
sns.jointplot(data=df, x="bill_length_mm", y="bill_depth_mm", hue="species")

# %%
#type your code here:

# %%
sns.jointplot(data=df, x="bill_length_mm", y="bill_depth_mm", kind="hex")

# %%
#type your code here:

# %% [markdown]
# - [swarmplot](https://seaborn.pydata.org/generated/seaborn.swarmplot.html)

# %%
sns.swarmplot(data=df, x="body_mass_g", y="sex", hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='sex'>

# %%
#type your code here:
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='sex'>

# %% [markdown]
# - [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
sns.boxplot(data=df, x="species", y="body_mass_g")
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
#type your code here:
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# #### Another interesting examples:
#
# - https://seaborn.pydata.org/examples/marginal_ticks.html
# - https://seaborn.pydata.org/examples/layered_bivariate_plot.html
# - https://seaborn.pydata.org/examples/joint_kde.html
# - https://seaborn.pydata.org/examples/joint_histogram.html
# - https://seaborn.pydata.org/examples/jitter_stripplot.html
# - https://seaborn.pydata.org/examples/horizontal_boxplot.html

# %% [markdown]
# (b) Exploring iris data:

# %%
df = pd.read_csv(r"E:\ITI AI&ML\10.Data Preparation\Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df, hue="Species")

# %%
sns.pairplot(df, hue="species")

# %% [markdown]
# # Problem 3: Practicing the Central Limit Theorem
# Use Python to simulate the Central Limit Theorem for the following random i.i.d variables and check that the higher the number of number the variables, the more the mean of subsets behave like a gaussian random variable.
