# %% [markdown]
# # Extra 3 - Working with GroupBy
#
# <img src="https://raw.githubusercontent.com/fralfaro/DS-Cheat-Sheets/main/docs/examples/pandas/pandas.png" alt="numpy logo" width = "300">

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({"key":list("ABC")*2,
                 "data1":range(6),
                 "data2":np.arange(5,11)})

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      6
# 2   C      2      7
# 3   A      3      8
# 4   B      4      9
# 5   C      5     10

# %%
group=df.groupby("key")

# %%
group.aggregate(["min",np.median,"max"])
# Out:
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     5    6.5   8
# B       1    2.5   4     6    7.5   9
# C       2    3.5   5     7    8.5  10

# %%
group.agg({"data1":"min","data2":"max"})
# Out:
#      data1  data2
# key
# A        0      8
# B        1      9
# C        2     10

# %%
def f(x):
    return x.max()-x.min()

# %%
group.agg(f)
# Out:
#      data1  data2
# key
# A        3      3
# B        3      3
# C        3      3

# %% [markdown]
# ## Applying more than one function

# %%
data=pd.DataFrame({"letter":list("ABC")*4,
                   "num":["one","two"]*6,
                   "d1":np.random.randn(12),
                   "d2":np.arange(10,33,2)})

# %%
data
# Out:
#    letter  num        d1  d2
# 0       A  one -1.505951  10
# 1       B  two -0.791578  12
# 2       C  one  1.823307  14
# 3       A  two -0.441780  16
# 4       B  one  0.419295  18
# 5       C  two -0.419544  20
# 6       A  one -1.097529  22
# 7       B  two -0.042220  24
# 8       C  one -2.177508  26
# 9       A  two  0.331912  28
# 10      B  one -0.004546  30
# 11      C  two  0.728714  32

# %%
group=data.groupby(["letter","num"])

# %%
group_d1=group["d1"]

# %%
group_d1.agg("mean")
# Out:
# letter  num
# A       one   -1.301740
#         two   -0.054934
# B       one    0.207374
#         two   -0.416899
# C       one   -0.177100
#         two    0.154585
# Name: d1, dtype: float64

# %%
group_d1.agg(["mean","std",f])
# Out:
#                 mean       std         f
# letter num
# A      one -1.301740  0.288798  0.408422
#        two -0.054934  0.547083  0.773692
# B      one  0.207374  0.299701  0.423841
#        two -0.416899  0.529877  0.749359
# C      one -0.177100  2.829004  4.000815
#        two  0.154585  0.811941  1.148258

# %%
group_d1.agg([("f_mean","mean"),
              ("f_std",np.std)])
# Out:
#               f_mean     f_std
# letter num
# A      one -1.301740  0.288798
#        two -0.054934  0.547083
# B      one  0.207374  0.299701
#        two -0.416899  0.529877
# C      one -0.177100  2.829004
#        two  0.154585  0.811941

# %%
group.agg({"d1":["count","max","mean"],
           "d2":"sum"})
# Out:
#               d1                      d2
#            count       max      mean sum
# letter num
# A      one     2 -1.097529 -1.301740  32
#        two     2  0.331912 -0.054934  44
# B      one     2  0.419295  0.207374  48
#        two     2 -0.042220 -0.416899  36
# C      one     2  1.823307 -0.177100  40
#        two     2  0.728714  0.154585  52

# %%
data.groupby(["letter","num"],
             as_index=False).mean()
# Out:
#   letter  num        d1    d2
# 0      A  one -1.301740  16.0
# 1      A  two -0.054934  22.0
# 2      B  one  0.207374  24.0
# 3      B  two -0.416899  18.0
# 4      C  one -0.177100  20.0
# 5      C  two  0.154585  26.0

# %% [markdown]
# ## Split-Apply-Combine

# %%
data
# Out:
#    letter  num        d1  d2
# 0       A  one -1.505951  10
# 1       B  two -0.791578  12
# 2       C  one  1.823307  14
# 3       A  two -0.441780  16
# 4       B  one  0.419295  18
# 5       C  two -0.419544  20
# 6       A  one -1.097529  22
# 7       B  two -0.042220  24
# 8       C  one -2.177508  26
# 9       A  two  0.331912  28
# 10      B  one -0.004546  30
# 11      C  two  0.728714  32

# %%
group=data.groupby("letter")

# %%
group["d2"].apply(lambda x:x.describe())
# Out:
# letter
# A       count     4.000000
#         mean     19.000000
#         std       7.745967
#         min      10.000000
#         25%      14.500000
#         50%      19.000000
#         75%      23.500000
#         max      28.000000
# B       count     4.000000
#         mean     21.000000
#         std       7.745967
#         min      12.000000
#         25%      16.500000
#         50%      21.000000
#         75%      25.500000
#         max      30.000000
# C       count     4.000000
#         mean     23.000000
#         std       7.745967
#         min      14.000000
#         25%      18.500000
#         50%      23.000000
#         75%      27.500000
#         max      32.000000
# Name: d2, dtype: float64

# %%
math=pd.DataFrame({"Class":list("AB")*3,
                   "Stu":["Kim","Sam",
                          "Tim","Tom","John","Kate"],
                   "Score":[60,70,np.nan,
                            55,np.nan,80]})
math
# Out:
#   Class   Stu  Score
# 0     A   Kim   60.0
# 1     B   Sam   70.0
# 2     A   Tim    NaN
# 3     B   Tom   55.0
# 4     A  John    NaN
# 5     B  Kate   80.0

# %%
group=math.groupby("Class")

# %%
group.mean()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18816\3928442431.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group.mean()
#            Score
# Class
# A      60.000000
# B      68.333333

# %%
func=lambda f:f.fillna(f.mean())

# %%
group.apply(func)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18816\2055239539.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   func=lambda f:f.fillna(f.mean())
# C:\Users\PC\AppData\Local\Temp\ipykernel_18816\2055239539.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   func=lambda f:f.fillna(f.mean())
# C:\Users\PC\AppData\Local\Temp\ipykernel_18816\3149468892.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   group.apply(func)
#   Class   Stu  Score
# 0     A   Kim   60.0
# 1     B   Sam   70.0
# 2     A   Tim   60.0
# 3     B   Tom   55.0
# 4     A  John   60.0
# 5     B  Kate   80.0

# %%
value={"A":100,"B":50}

# %%
func1=lambda f:f.fillna(value[f.name])

# %%
group.apply(func1)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18816\1325833793.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   group.apply(func1)
#   Class   Stu  Score
# 0     A   Kim   60.0
# 1     B   Sam   70.0
# 2     A   Tim  100.0
# 3     B   Tom   55.0
# 4     A  John  100.0
# 5     B  Kate   80.0
