# %% [markdown]
# # Extra 4 - Pivot Tables
#
# <img src="https://raw.githubusercontent.com/fralfaro/DS-Cheat-Sheets/main/docs/examples/pandas/pandas.png" alt="numpy logo" width = "300">

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(
    {"class":list("ABC")*4,
     "lesson":["math","stat"]*6,
     "sex":list("MFMM")*3,
     "sibling":[1,2,3]*4,
     "score":np.arange(40,100,5)})

# %%
df
# Out:
#    class lesson sex  sibling  score
# 0      A   math   M        1     40
# 1      B   stat   F        2     45
# 2      C   math   M        3     50
# 3      A   stat   M        1     55
# 4      B   math   M        2     60
# 5      C   stat   F        3     65
# 6      A   math   M        1     70
# 7      B   stat   M        2     75
# 8      C   math   M        3     80
# 9      A   stat   F        1     85
# 10     B   math   M        2     90
# 11     C   stat   M        3     95

# %%
df.groupby("lesson")["score"].mean()
# Out:
# lesson
# math    65.0
# stat    70.0
# Name: score, dtype: float64

# %%
df.groupby(
    ["lesson",
     "class"])[
    "score"].aggregate("mean").unstack()
# Out:
# class      A     B     C
# lesson
# math    55.0  75.0  65.0
# stat    70.0  60.0  80.0

# %%
df.pivot_table(
    "score",
    index="lesson",
    columns="class")
# Out:
# class    A   B   C
# lesson
# math    55  75  65
# stat    70  60  80

# %%
df.pivot_table(
    ["sibling","score"],
    index=["class","lesson"],
    columns="sex")
# Out:
#              score       sibling
# sex              F     M       F    M
# class lesson
# A     math     NaN  55.0     NaN  1.0
#       stat    85.0  55.0     1.0  1.0
# B     math     NaN  75.0     NaN  2.0
#       stat    45.0  75.0     2.0  2.0
# C     math     NaN  65.0     NaN  3.0
#       stat    65.0  95.0     3.0  3.0

# %%
df.pivot_table(
    ["sibling","score"],
    index=["class","lesson"],
    columns="sex",margins=True)
# Out:
#              score                  sibling
# sex              F          M   All       F    M  All
# class lesson
# A     math     NaN  55.000000  55.0     NaN  1.0  1.0
#       stat    85.0  55.000000  70.0     1.0  1.0  1.0
# B     math     NaN  75.000000  75.0     NaN  2.0  2.0
#       stat    45.0  75.000000  60.0     2.0  2.0  2.0
# C     math     NaN  65.000000  65.0     NaN  3.0  3.0
#       stat    65.0  95.000000  80.0     3.0  3.0  3.0
# All           65.0  68.333333  67.5     2.0  2.0  2.0

# %%
df.pivot_table(
    ["sibling","score"],
    index=["class","lesson"],
    columns="sex",fill_value=0)
# Out:
#              score     sibling
# sex              F   M       F  M
# class lesson
# A     math       0  55       0  1
#       stat      85  55       1  1
# B     math       0  75       0  2
#       stat      45  75       2  2
# C     math       0  65       0  3
#       stat      65  95       3  3

# %% [markdown]
# ## Multi-level pivot tables

# %%
sib=pd.cut(df["sibling"],[0,2,3])

# %%
df.pivot_table("score",
               ["lesson",sib],
               "class",fill_value=0)
# Out:
# class            A   B   C
# lesson sibling
# math   (0, 2]   55  75   0
#        (2, 3]    0   0  65
# stat   (0, 2]   70  60   0
#        (2, 3]    0   0  80

# %%
df.pivot_table(
    "score",
    index="lesson",
    columns="class")
# Out:
# class    A   B   C
# lesson
# math    55  75  65
# stat    70  60  80

# %%
df.pivot_table(
    index="lesson",
    columns="class",
    aggfunc="sum")
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_22544\1763770086.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(
#        score           sibling
# class      A    B    C       A  B  C
# lesson
# math     110  150  130       2  4  6
# stat     140  120  160       2  4  6

# %%
df.pivot_table(
    index="lesson",
    columns="class",
    aggfunc={"sibling":"max",
             "score":"sum"})
# Out:
#        score           sibling
# class      A    B    C       A  B  C
# lesson
# math     110  150  130       1  2  3
# stat     140  120  160       1  2  3

# %% [markdown]
# ## Cross-Tabulations: Crosstab

# %%
pd.crosstab(df.sibling,df.lesson)
# Out:
# lesson   math  stat
# sibling
# 1           2     2
# 2           2     2
# 3           2     2

# %%
pd.crosstab([df.sibling, df.lesson], df.sex)
# Out:
# sex             F  M
# sibling lesson
# 1       math    0  2
#         stat    1  1
# 2       math    0  2
#         stat    1  1
# 3       math    0  2
#         stat    1  1

# %% [markdown]
# You can download the data set from https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv

# %%
births=pd.read_csv("Data/births.txt")

# %%
births.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
births["ten_year"]=10*(births["year"]//10)
births.pivot_table("births",
                   index="ten_year",
                   columns="gender",
                   aggfunc="sum")
# Out:
# gender           F         M
# ten_year
# 1960       1753634   1846572
# 1970      16263075  17121550
# 1980      18310351  19243452
# 1990      19479454  20420553
# 2000      18229309  19106428

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set() #For style

# %%
births.pivot_table("births",
                   index="year",
                   columns="gender",
                   aggfunc="sum").plot()
plt.ylabel("Annual total births")
# Out:
# Text(0, 0.5, 'Annual total births')
